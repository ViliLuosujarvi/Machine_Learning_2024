# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn import metrics, svm
from sklearn.pipeline import make_pipeline
from sklearn.calibration import CalibratedClassifierCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from keras import utils

# %%
# Read csv
df = pd.read_csv('commodity 2000-2022.csv')

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  29935.000000  29935.000000  29935.000000  29935.000000  2.993500e+04
# mean    2199.912965   2217.497624   2183.193574   2200.980681  5.272722e+04
# std     5054.172000   5088.374345   5024.451547   5054.979572  8.280148e+04
# min        0.000000      0.000000      0.000000      1.482000  0.000000e+00
# 25%       48.075000     48.975000     47.265000     48.140000  1.000000e+00
# 50%      431.300000    435.500000    428.000000    431.400000  1.157100e+04
# 75%     1165.300000   1173.050000   1158.050000   1168.600000  7.218800e+04
# max    81066.500000  86791.500000  81031.500000  81051.500000  1.083978e+06

# %%
df['Symbol'].unique()
# Out:
# array(['Gold', 'Palladium', 'Nickel', 'Brent Oil', 'Natural Gas',
#        'US Wheat'], dtype=object)

# %%
# Replace string values into integers
# In integer values:
# Gold = 0, Palladium = 1, Nickel = 2, Brent Oil = 3, Natural Gas = 4 and US Wheat = 5
df = df.replace({'Gold': 0, 'Palladium': 1, 'Nickel': 2, 'Brent Oil': 3, 'Natural Gas': 4, 'US Wheat': 5})
# Out:
# C:\Users\vilil\AppData\Local\Temp\ipykernel_23064\363166622.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace({'Gold': 0, 'Palladium': 1, 'Nickel': 2, 'Brent Oil': 3, 'Natural Gas': 4, 'US Wheat': 5})

# %%
df
# Out:
#        Symbol        Date     Open     High      Low    Close  Volume
# 0           0  2000-01-04   281.00   281.00   281.00   282.70       4
# 1           0  2000-01-05   283.20   283.20   283.20   281.10      16
# 2           0  2000-01-06   281.40   281.40   281.40   281.40       0
# 3           0  2000-01-07   281.90   281.90   281.90   281.90       0
# 4           0  2000-01-10   281.70   281.70   281.70   281.70       0
# ...       ...         ...      ...      ...      ...      ...     ...
# 29930       5  2022-04-04   989.50  1014.50   984.75  1010.25       0
# 29931       5  2022-04-05  1020.50  1074.00  1020.00  1045.25       0
# 29932       5  2022-04-06  1049.40  1056.40  1024.25  1041.12       0
# 29933       5  2022-04-07  1040.25  1044.50  1017.75  1020.00       0
# 29934       5  2022-04-08  1020.00  1054.25  1017.00  1051.50       0
#
# [29935 rows x 7 columns]

# %%
# convert the date column into a datetime object
df['Date'] = pd.to_datetime(df['Date'])

# extract the day, month, and year components
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# show the modified data frame
print(df)
# Out:
#        Symbol       Date     Open     High      Low    Close  Volume  Day  \
# 0           0 2000-01-04   281.00   281.00   281.00   282.70       4    4
# 1           0 2000-01-05   283.20   283.20   283.20   281.10      16    5
# 2           0 2000-01-06   281.40   281.40   281.40   281.40       0    6
# 3           0 2000-01-07   281.90   281.90   281.90   281.90       0    7
# 4           0 2000-01-10   281.70   281.70   281.70   281.70       0   10
# ...       ...        ...      ...      ...      ...      ...     ...  ...
# 29930       5 2022-04-04   989.50  1014.50   984.75  1010.25       0    4
# 29931       5 2022-04-05  1020.50  1074.00  1020.00  1045.25       0    5
# 29932       5 2022-04-06  1049.40  1056.40  1024.25  1041.12       0    6
# 29933       5 2022-04-07  1040.25  1044.50  1017.75  1020.00       0    7
# 29934       5 2022-04-08  1020.00  1054.25  1017.00  1051.50       0    8
#
#        Month  Year
# 0          1  2000
# 1          1  2000
# 2          1  2000
# 3          1  2000
# 4          1  2000
# ...      ...   ...
# 29930      4  2022
# 29931      4  2022
# 29932      4  2022
# 29933      4  2022
# 29934      4  2022
#
# [29935 rows x 10 columns]

# %%
# drop unneccesary "Date" because now on we'll use it in day, month and year sections
df = df.drop('Date', axis=1)

print(df)
# Out:
#        Symbol     Open     High      Low    Close  Volume  Day  Month  Year
# 0           0   281.00   281.00   281.00   282.70       4    4      1  2000
# 1           0   283.20   283.20   283.20   281.10      16    5      1  2000
# 2           0   281.40   281.40   281.40   281.40       0    6      1  2000
# 3           0   281.90   281.90   281.90   281.90       0    7      1  2000
# 4           0   281.70   281.70   281.70   281.70       0   10      1  2000
# ...       ...      ...      ...      ...      ...     ...  ...    ...   ...
# 29930       5   989.50  1014.50   984.75  1010.25       0    4      4  2022
# 29931       5  1020.50  1074.00  1020.00  1045.25       0    5      4  2022
# 29932       5  1049.40  1056.40  1024.25  1041.12       0    6      4  2022
# 29933       5  1040.25  1044.50  1017.75  1020.00       0    7      4  2022
# 29934       5  1020.00  1054.25  1017.00  1051.50       0    8      4  2022
#
# [29935 rows x 9 columns]

# %%
# Find out if dataset contains any missing values
df.isna().sum()
# Out:
# Symbol    0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Day       0
# Month     0
# Year      0
# dtype: int64

# %%
# Find out if dataset contains any duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# a common trick in X/y -split
# X = everything else in the DataFrame minus the target variable
# y = only the target variable
X = df.drop('Symbol', axis=1)
y = df['Symbol']

# %%
df
# Out:
#        Symbol     Open     High      Low    Close  Volume  Day  Month  Year
# 0           0   281.00   281.00   281.00   282.70       4    4      1  2000
# 1           0   283.20   283.20   283.20   281.10      16    5      1  2000
# 2           0   281.40   281.40   281.40   281.40       0    6      1  2000
# 3           0   281.90   281.90   281.90   281.90       0    7      1  2000
# 4           0   281.70   281.70   281.70   281.70       0   10      1  2000
# ...       ...      ...      ...      ...      ...     ...  ...    ...   ...
# 29930       5   989.50  1014.50   984.75  1010.25       0    4      4  2022
# 29931       5  1020.50  1074.00  1020.00  1045.25       0    5      4  2022
# 29932       5  1049.40  1056.40  1024.25  1041.12       0    6      4  2022
# 29933       5  1040.25  1044.50  1017.75  1020.00       0    7      4  2022
# 29934       5  1020.00  1054.25  1017.00  1051.50       0    8      4  2022
#
# [29935 rows x 9 columns]

# %%
# version 1, SciPy, extreme outliers that go under -3 or over +3 in normal distribution
from scipy import stats
df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

# version 2, use quantiles
 #this removes top 10% and bottom 10% from the distribution (extreme values)
 #price is used as the variable. you can also use this for other variables, like area
#df_middle= df.query('Close >= Close.quantile(q=0.40) and Close < Close.quantile(q=0.60)')

# %%
# Check if values have changed due to getting rid of the outliers
df.describe()
# Out:
#              Symbol          Open          High           Low         Close  \
# count  28204.000000  28204.000000  28204.000000  28204.000000  28204.000000
# mean       2.669692   1503.596308   1519.025732   1488.693267   1504.669178
# std        1.823243   3483.430196   3520.506606   3448.694922   3484.538411
# min        0.000000      0.000000      0.000000      0.000000      1.482000
# 25%        1.000000     42.550000     43.395000     41.600000     42.715000
# 50%        3.000000    420.225000    423.225000    417.000000    420.225000
# 75%        4.000000    939.025000    947.825000    931.075000    938.275000
# max        5.000000  17351.000000  17475.000000  17241.000000  17357.000000
#
#               Volume           Day         Month          Year
# count   28204.000000  28204.000000  28204.000000  28204.000000
# mean    47855.838214     15.792193      6.505283   2011.584598
# std     69921.067960      8.785399      3.450257      6.255584
# min         0.000000      1.000000      1.000000   2000.000000
# 25%         3.000000      8.000000      3.000000   2007.000000
# 50%     11628.500000     16.000000      7.000000   2012.000000
# 75%     69478.500000     23.000000     10.000000   2017.000000
# max    301107.000000     31.000000     12.000000   2022.000000

# %%
df
# Out:
#        Symbol     Open     High      Low    Close  Volume  Day  Month  Year
# 0           0   281.00   281.00   281.00   282.70       4    4      1  2000
# 1           0   283.20   283.20   283.20   281.10      16    5      1  2000
# 2           0   281.40   281.40   281.40   281.40       0    6      1  2000
# 3           0   281.90   281.90   281.90   281.90       0    7      1  2000
# 4           0   281.70   281.70   281.70   281.70       0   10      1  2000
# ...       ...      ...      ...      ...      ...     ...  ...    ...   ...
# 29930       5   989.50  1014.50   984.75  1010.25       0    4      4  2022
# 29931       5  1020.50  1074.00  1020.00  1045.25       0    5      4  2022
# 29932       5  1049.40  1056.40  1024.25  1041.12       0    6      4  2022
# 29933       5  1040.25  1044.50  1017.75  1020.00       0    7      4  2022
# 29934       5  1020.00  1054.25  1017.00  1051.50       0    8      4  2022
#
# [28204 rows x 9 columns]

# %%
# REMEMBER TO SCALE THE TARGET VARIABLE (y)
# WITH MINMAXSCALER BEFORE DOING THE X/y -split

# initalize scaler
scalerY = MinMaxScaler()

# name of target variable
target_variable = "Symbol"

# save min/max -values of target value
# for bettermetrics later
min_y = df[target_variable].min()
max_y = df[target_variable].max()

# scale y-variable
num_vars = [target_variable]
df[num_vars] = scalerY.fit_transform(df[num_vars])
# Out:
# C:\Users\vilil\AppData\Local\Temp\ipykernel_23064\2286891684.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[num_vars] = scalerY.fit_transform(df[num_vars])

# %%
# create train and test sets of your dataset
# random_state is optional, you can lock this down in order to 
# to get same results always
# this examples reserves 30% for test data, 70% for training data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25) #, random_state=101)

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y_train)
encoded_y = encoder.transform(y_train)

# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = utils.to_categorical(encoded_y)

# %%
# displaying the datatypes
display(df.dtypes)
 
# converting all columns from float to int
df = df.astype({"Symbol": 'int', "Open": 'int', "High": 'int',"Low": 'int',"Volume": 'int',"Close": 'int'})
# 'Open', 'High', 'Low', 'Volume'
 
# displaying the datatypes
display(df.dtypes)
# Out:
# Symbol    float64
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# Day         int32
# Month       int32
# Year        int32
# dtype: object
# Symbol    int32
# Open      int32
# High      int32
# Low       int32
# Close     int32
# Volume    int32
# Day       int32
# Month     int32
# Year      int32
# dtype: object

# %%
df
# Out:
#        Symbol  Open  High   Low  Close  Volume  Day  Month  Year
# 0           0   281   281   281    282       4    4      1  2000
# 1           0   283   283   283    281      16    5      1  2000
# 2           0   281   281   281    281       0    6      1  2000
# 3           0   281   281   281    281       0    7      1  2000
# 4           0   281   281   281    281       0   10      1  2000
# ...       ...   ...   ...   ...    ...     ...  ...    ...   ...
# 29930       1   989  1014   984   1010       0    4      4  2022
# 29931       1  1020  1074  1020   1045       0    5      4  2022
# 29932       1  1049  1056  1024   1041       0    6      4  2022
# 29933       1  1040  1044  1017   1020       0    7      4  2022
# 29934       1  1020  1054  1017   1051       0    8      4  2022
#
# [28204 rows x 9 columns]

# %%
 from sklearn.model_selection import GridSearchCV

# {'C': 1.25, 'gamma': 0.1, 'kernel': 'sigmoid'}

# So far best resutls:
# {'C': 1.5, 'gamma': 0.1, 'kernel': 'linear'}
param_grid = {
    'C': [1, 1.25, 1.5],
    #"epsilon": [0.075, 0.1, 0.15],
    #"nu": [0.15, 0.2, 0.25, 0.3, 0.4, 0.45],
    "gamma": [0.1, 0.15, 0.25],
    "kernel": ["rbf", "linear"]
}

# create and fit the model
model = make_pipeline(StandardScaler(), GridSearchCV(svm.SVC(probability=True), param_grid, refit=True, verbose=3))
#model = make_pipeline(StandardScaler(), svm.SVC(probability=True))

model.fit(X_train, y_train)

# show the best parameters which GridSearchCV eventually found
model[1].best_params_
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.761 total time=  35.9s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.761 total time=  34.9s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.765 total time=  35.1s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.787 total time=  35.5s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.773 total time=  33.1s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.796 total time=  16.9s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.794 total time=  17.9s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.793 total time=  18.4s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.802 total time=  17.7s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.801 total time=  18.0s
# [CV 1/5] END .......C=1, gamma=0.15, kernel=rbf;, score=0.773 total time=  33.7s
# [CV 2/5] END .......C=1, gamma=0.15, kernel=rbf;, score=0.773 total time=  33.5s
# [CV 3/5] END .......C=1, gamma=0.15, kernel=rbf;, score=0.774 total time=  33.2s
# [CV 4/5] END .......C=1, gamma=0.15, kernel=rbf;, score=0.792 total time=  31.1s
# [CV 5/5] END .......C=1, gamma=0.15, kernel=rbf;, score=0.784 total time=  32.2s
# [CV 1/5] END ....C=1, gamma=0.15, kernel=linear;, score=0.796 total time=  17.3s
# [CV 2/5] END ....C=1, gamma=0.15, kernel=linear;, score=0.794 total time=  17.6s
# [CV 3/5] END ....C=1, gamma=0.15, kernel=linear;, score=0.793 total time=  18.4s
# [CV 4/5] END ....C=1, gamma=0.15, kernel=linear;, score=0.802 total time=  17.7s
# [CV 5/5] END ....C=1, gamma=0.15, kernel=linear;, score=0.801 total time=  18.6s
# [CV 1/5] END .......C=1, gamma=0.25, kernel=rbf;, score=0.792 total time=  32.1s
# [CV 2/5] END .......C=1, gamma=0.25, kernel=rbf;, score=0.787 total time=  30.0s
# [CV 3/5] END .......C=1, gamma=0.25, kernel=rbf;, score=0.791 total time=  31.6s
# [CV 4/5] END .......C=1, gamma=0.25, kernel=rbf;, score=0.800 total time=  31.2s
# [CV 5/5] END .......C=1, gamma=0.25, kernel=rbf;, score=0.793 total time=  30.9s
# [CV 1/5] END ....C=1, gamma=0.25, kernel=linear;, score=0.796 total time=  17.6s
# [CV 2/5] END ....C=1, gamma=0.25, kernel=linear;, score=0.794 total time=  18.2s
# [CV 3/5] END ....C=1, gamma=0.25, kernel=linear;, score=0.793 total time=  18.9s
# [CV 4/5] END ....C=1, gamma=0.25, kernel=linear;, score=0.802 total time=  20.4s
# [CV 5/5] END ....C=1, gamma=0.25, kernel=linear;, score=0.801 total time=  19.3s
# [CV 1/5] END .....C=1.25, gamma=0.1, kernel=rbf;, score=0.769 total time=  33.9s
# [CV 2/5] END .....C=1.25, gamma=0.1, kernel=rbf;, score=0.766 total time=  28.7s
# [CV 3/5] END .....C=1.25, gamma=0.1, kernel=rbf;, score=0.771 total time=  28.1s
# [CV 4/5] END .....C=1.25, gamma=0.1, kernel=rbf;, score=0.787 total time=  28.7s
# [CV 5/5] END .....C=1.25, gamma=0.1, kernel=rbf;, score=0.776 total time=  28.4s
# [CV 1/5] END ..C=1.25, gamma=0.1, kernel=linear;, score=0.803 total time=  15.2s
# [CV 2/5] END ..C=1.25, gamma=0.1, kernel=linear;, score=0.802 total time=  15.2s
# [CV 3/5] END ..C=1.25, gamma=0.1, kernel=linear;, score=0.803 total time=  15.0s
# [CV 4/5] END ..C=1.25, gamma=0.1, kernel=linear;, score=0.811 total time=  15.2s
# [CV 5/5] END ..C=1.25, gamma=0.1, kernel=linear;, score=0.806 total time=  15.3s
# [CV 1/5] END ....C=1.25, gamma=0.15, kernel=rbf;, score=0.782 total time=  27.4s
# [CV 2/5] END ....C=1.25, gamma=0.15, kernel=rbf;, score=0.784 total time=  27.3s
# [CV 3/5] END ....C=1.25, gamma=0.15, kernel=rbf;, score=0.783 total time=  27.5s
# [CV 4/5] END ....C=1.25, gamma=0.15, kernel=rbf;, score=0.798 total time=  27.3s
# [CV 5/5] END ....C=1.25, gamma=0.15, kernel=rbf;, score=0.790 total time=  27.7s
# [CV 1/5] END .C=1.25, gamma=0.15, kernel=linear;, score=0.803 total time=  15.4s
# [CV 2/5] END .C=1.25, gamma=0.15, kernel=linear;, score=0.802 total time=  15.2s
# [CV 3/5] END .C=1.25, gamma=0.15, kernel=linear;, score=0.803 total time=  14.9s
# [CV 4/5] END .C=1.25, gamma=0.15, kernel=linear;, score=0.811 total time=  15.0s
# [CV 5/5] END .C=1.25, gamma=0.15, kernel=linear;, score=0.806 total time=  15.1s
# [CV 1/5] END ....C=1.25, gamma=0.25, kernel=rbf;, score=0.804 total time=  26.3s
# [CV 2/5] END ....C=1.25, gamma=0.25, kernel=rbf;, score=0.794 total time=  25.8s
# [CV 3/5] END ....C=1.25, gamma=0.25, kernel=rbf;, score=0.797 total time=  25.5s
# [CV 4/5] END ....C=1.25, gamma=0.25, kernel=rbf;, score=0.804 total time=  25.6s
# [CV 5/5] END ....C=1.25, gamma=0.25, kernel=rbf;, score=0.801 total time=  25.7s
# [CV 1/5] END .C=1.25, gamma=0.25, kernel=linear;, score=0.803 total time=  14.9s
# [CV 2/5] END .C=1.25, gamma=0.25, kernel=linear;, score=0.802 total time=  14.8s
# [CV 3/5] END .C=1.25, gamma=0.25, kernel=linear;, score=0.803 total time=  14.7s
# [CV 4/5] END .C=1.25, gamma=0.25, kernel=linear;, score=0.811 total time=  14.7s
# [CV 5/5] END .C=1.25, gamma=0.25, kernel=linear;, score=0.806 total time=  15.0s
# [CV 1/5] END ......C=1.5, gamma=0.1, kernel=rbf;, score=0.773 total time=  26.6s
# [CV 2/5] END ......C=1.5, gamma=0.1, kernel=rbf;, score=0.772 total time=  26.8s
# [CV 3/5] END ......C=1.5, gamma=0.1, kernel=rbf;, score=0.774 total time=  26.6s
# [CV 4/5] END ......C=1.5, gamma=0.1, kernel=rbf;, score=0.792 total time=  26.9s
# [CV 5/5] END ......C=1.5, gamma=0.1, kernel=rbf;, score=0.783 total time=  26.8s
# [CV 1/5] END ...C=1.5, gamma=0.1, kernel=linear;, score=0.807 total time=  15.0s
# [CV 2/5] END ...C=1.5, gamma=0.1, kernel=linear;, score=0.806 total time=  15.5s
# [CV 3/5] END ...C=1.5, gamma=0.1, kernel=linear;, score=0.808 total time=  14.9s
# [CV 4/5] END ...C=1.5, gamma=0.1, kernel=linear;, score=0.814 total time=  15.5s
# [CV 5/5] END ...C=1.5, gamma=0.1, kernel=linear;, score=0.809 total time=  15.4s
# [CV 1/5] END .....C=1.5, gamma=0.15, kernel=rbf;, score=0.790 total time=  25.5s
# [CV 2/5] END .....C=1.5, gamma=0.15, kernel=rbf;, score=0.790 total time=  25.8s
# [CV 3/5] END .....C=1.5, gamma=0.15, kernel=rbf;, score=0.788 total time=  25.5s
# [CV 4/5] END .....C=1.5, gamma=0.15, kernel=rbf;, score=0.804 total time=  28.1s
# [CV 5/5] END .....C=1.5, gamma=0.15, kernel=rbf;, score=0.794 total time=  25.9s
# [CV 1/5] END ..C=1.5, gamma=0.15, kernel=linear;, score=0.807 total time=  16.3s
# [CV 2/5] END ..C=1.5, gamma=0.15, kernel=linear;, score=0.806 total time=  15.5s
# [CV 3/5] END ..C=1.5, gamma=0.15, kernel=linear;, score=0.808 total time=  15.5s
# [CV 4/5] END ..C=1.5, gamma=0.15, kernel=linear;, score=0.814 total time=  15.1s
# [CV 5/5] END ..C=1.5, gamma=0.15, kernel=linear;, score=0.809 total time=  15.5s
# [CV 1/5] END .....C=1.5, gamma=0.25, kernel=rbf;, score=0.809 total time=  25.2s
# [CV 2/5] END .....C=1.5, gamma=0.25, kernel=rbf;, score=0.801 total time=  24.6s
# [CV 3/5] END .....C=1.5, gamma=0.25, kernel=rbf;, score=0.801 total time=  24.7s
# [CV 4/5] END .....C=1.5, gamma=0.25, kernel=rbf;, score=0.810 total time=  24.7s
# [CV 5/5] END .....C=1.5, gamma=0.25, kernel=rbf;, score=0.810 total time=  24.4s
# [CV 1/5] END ..C=1.5, gamma=0.25, kernel=linear;, score=0.807 total time=  15.0s
# [CV 2/5] END ..C=1.5, gamma=0.25, kernel=linear;, score=0.806 total time=  15.0s
# [CV 3/5] END ..C=1.5, gamma=0.25, kernel=linear;, score=0.808 total time=  14.9s
# [CV 4/5] END ..C=1.5, gamma=0.25, kernel=linear;, score=0.814 total time=  14.6s
# [CV 5/5] END ..C=1.5, gamma=0.25, kernel=linear;, score=0.809 total time=  15.3s
# {'C': 1.5, 'gamma': 0.1, 'kernel': 'linear'}

# %%
# create an empty linear regression model
# and fit it with out data 
#model = make_pipeline(StandardScaler(), svm.SVC(probability=True))
#model.fit(X_train, y_train)

# %%
# make test predictions with new data with our model
predictions = model.predict(X_test)

# %%
 # print the classification report based on true values and predictions
print(classification_report(y_test, predictions))

# get overall accuracy of the model and print it
acc = accuracy_score(y_test, predictions)
print("\nModel overall accuracy: {:.2f}%".format(acc * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      1451
#            1       0.57      0.57      0.57       900
#            2       1.00      1.00      1.00       868
#            3       1.00      0.76      0.86      1402
#            4       0.81      1.00      0.90      1443
#            5       0.82      0.69      0.75      1420
#
#     accuracy                           0.82      7484
#    macro avg       0.83      0.82      0.82      7484
# weighted avg       0.83      0.82      0.82      7484
#
#
# Model overall accuracy: 82.04%

# %%
labels = ['Gold', 'Palladium', 'Nickel', 'Brent Oil', 'Natural Gas', 'US Wheat']

# %%
print(confusion_matrix(y_test, predictions))
print("\n")

# use seaborn to make a nicer confusion matrix
cm_array = confusion_matrix(y_test, predictions)
cm_array_df = pd.DataFrame(cm_array, index=labels, columns=labels)
sns.heatmap(cm_array_df, annot=True, annot_kws={"size": 12})
# Out:
# [[1261  132    0    0    0   58]
#  [ 230  516    0    0    0  154]
#  [   0    0  868    0    0    0]
#  [   0    0    0 1072  330    0]
#  [   0    0    0    5 1438    0]
#  [ 171  264    0    0    0  985]]
# <Axes: >

# %%
df.describe()
# Out:
#              Symbol          Open          High           Low         Close  \
# count  28204.000000  28204.000000  28204.000000  28204.000000  28204.000000
# mean       0.205574   1503.186250   1518.607644   1488.290207   1504.239824
# std        0.404127   3483.520697   3520.592324   3448.777872   3484.638130
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.000000     42.000000     43.000000     41.000000     42.000000
# 50%        0.000000    420.000000    423.000000    417.000000    420.000000
# 75%        0.000000    939.000000    947.000000    931.000000    938.000000
# max        1.000000  17351.000000  17475.000000  17241.000000  17357.000000
#
#               Volume           Day         Month          Year
# count   28204.000000  28204.000000  28204.000000  28204.000000
# mean    47855.838214     15.792193      6.505283   2011.584598
# std     69921.067960      8.785399      3.450257      6.255584
# min         0.000000      1.000000      1.000000   2000.000000
# 25%         3.000000      8.000000      3.000000   2007.000000
# 50%     11628.500000     16.000000      7.000000   2012.000000
# 75%     69478.500000     23.000000     10.000000   2017.000000
# max    301107.000000     31.000000     12.000000   2022.000000

# %%
# Create tester row to test your model
tester_row = {
    'Open': 3483,
    'High': 3520,
    'Low': 3448,
    'Close': 3484,
    'Volume': 69921,
    'Day': 3,
    'Month': 3,
    'Year': 12
}

# create a pandas DataFrame
tester_row = pd.DataFrame([tester_row])

# probabilities by all categories
print("All probabilities by category:")
print(model.predict_proba(tester_row))
print()

# change these based on your original data
# this is a nice thing in SVM ->
# you get actual category names as output instead
# index integers
print("Predicted category:")
result = model.predict(tester_row)[0]
print(result)
print("-------------------")
# Out:
# All probabilities by category:
# [[0.33153276 0.08291394 0.17039203 0.16574491 0.0837467  0.16566966]]
#
# Predicted category:
# 0
# -------------------
